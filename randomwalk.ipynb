# %% [markdown]
# <a href="https://colab.research.google.com/github/pesl/DL_Coursera/blob/master/randomwalk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import seed
from random import random
from matplotlib import pyplot
# %matplotlib inline
seed(1)

# %%
pyplot.figure(figsize=(10,10),dpi=100)

# init eerste waarde
if random() < 0.5:
  random_walk = [-1]
else:
  random_walk = [1]

for i in range(1, 10000):
    if random() < 0.5:
      movement = -1
    else:
      movement = 1
    value = random_walk[i-1] + movement
    random_walk.append(value)
pyplot.plot(random_walk)

pyplot.show()
